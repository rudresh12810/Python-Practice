# %% [markdown]
# # Python 201 Week 2 Assignment
# Complete information abpout the dataset is given below:
# https://archive.ics.uci.edu/ml/datasets/Absenteeism+at+work.
# Please go through the link and try to understand variables well before doing the assignment.

# %% [markdown]
# ## Q1: Import the pandas library, import the absenteeism dataset(provided) and assign it to “df”, and find out the “type” of the dataset.

# %%
 pip install xlrd
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.2.4; however, version 23.2.1 is available.
# You should consider upgrading via the 'C:\Pyhon39\python.exe -m pip install --upgrade pip' command.

# %%
import numpy as np
import pandas as pd

df = pd.read_excel("2181734-Absenteeism_at_work.xls")
df.head(5)
# Out:
#    ID  Reason for absence  Month of absence  Day of the week  Seasons  \
# 0  11                  26                 7                3        1
# 1  36                   0                 7                3        1
# 2   3                  23                 7                4        1
# 3   7                   7                 7                5        1
# 4  11                  23                 7                5        1
#
#    Transportation expense  Distance from Residence to Work  Service time  Age  \
# 0                     289                               36            13   33
# 1                     118                               13            18   50
# 2                     179                               51            18   38
# 3                     279                                5            14   39
# 4                     289                               36            13   33
#
#    Work load Average/day   ...  Disciplinary failure  Education  Son  \
# ...

# %% [markdown]
# ## Q2: Find the info of the data set.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 740 entries, 0 to 739
# Data columns (total 21 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   ID                               740 non-null    int64
#  1   Reason for absence               740 non-null    int64
#  2   Month of absence                 740 non-null    int64
#  3   Day of the week                  740 non-null    int64
#  4   Seasons                          740 non-null    int64
#  5   Transportation expense           740 non-null    int64
#  6   Distance from Residence to Work  740 non-null    int64
#  7   Service time                     740 non-null    int64
#  8   Age                              740 non-null    int64
#  9   Work load Average/day            740 non-null    int64
#  10  Hit target                       740 non-null    int64
#  11  Disciplinary failure             740 non-null    int64
# ...

# %% [markdown]
# ## Q3: Drop the first column “ID”, and save it back to “df”.

# %%
df.drop(["ID"], axis = 1, inplace = True)
df
# Out:
#      Reason for absence  Month of absence  Day of the week  Seasons  \
# 0                    26                 7                3        1
# 1                     0                 7                3        1
# 2                    23                 7                4        1
# 3                     7                 7                5        1
# 4                    23                 7                5        1
# ..                  ...               ...              ...      ...
# 735                  14                 7                3        1
# 736                  11                 7                3        1
# 737                   0                 0                3        1
# 738                   0                 0                4        2
# 739                   0                 0                6        3
#
#      Transportation expense  Distance from Residence to Work  Service time  \
# ...

# %% [markdown]
# ## Q4: Drop the age column. And save it back to “df”

# %%
df.drop(["Age"], axis=1, inplace = True)

# %% [markdown]
# ## Q5 What are the smallest and largest values of the column “reason for absence”.

# %%
print("Largest value of the column 'Reason for absence':",df["Reason for absence"].min())
print("Largest value of the column 'Reason for absence':",df["Reason for absence"].max())
# Out:
# Largest value of the column 'Reason for absence': 0
# Largest value of the column 'Reason for absence': 28

# %% [markdown]
# ## Q6: Create dummy variables for reason of absence and save it itno a new variable df_dummy_var.

# %%
df_dummy_var = pd.get_dummies(df, columns = ["Reason for absence"])
df_dummy_var.head()
# Out:
#    Month of absence  Day of the week  Seasons  Transportation expense  \
# 0                 7                3        1                     289
# 1                 7                3        1                     118
# 2                 7                4        1                     179
# 3                 7                5        1                     279
# 4                 7                5        1                     289
#
#    Distance from Residence to Work  Service time  Work load Average/day   \
# 0                               36            13                  239554
# 1                               13            18                  239554
# 2                               51            18                  239554
# 3                                5            14                  239554
# 4                               36            13                  239554
#
#    Hit target  Disciplinary failure  Education  ...  Reason for absence_18  \
# ...

# %%
df_dummy_var.columns
# Out:
# Index(['Month of absence', 'Day of the week', 'Seasons',
#        'Transportation expense', 'Distance from Residence to Work',
#        'Service time', 'Work load Average/day ', 'Hit target',
#        'Disciplinary failure', 'Education', 'Son', 'Social drinker',
#        'Social smoker', 'Pet', 'Weight', 'Height', 'Body mass index',
#        'Absenteeism time in hours', 'Reason for absence_0',
#        'Reason for absence_1', 'Reason for absence_2', 'Reason for absence_3',
#        'Reason for absence_4', 'Reason for absence_5', 'Reason for absence_6',
#        'Reason for absence_7', 'Reason for absence_8', 'Reason for absence_9',
#        'Reason for absence_10', 'Reason for absence_11',
#        'Reason for absence_12', 'Reason for absence_13',
#        'Reason for absence_14', 'Reason for absence_15',
#        'Reason for absence_16', 'Reason for absence_17',
#        'Reason for absence_18', 'Reason for absence_19',
#        'Reason for absence_21', 'Reason for absence_22',
# ...

# %% [markdown]
# ## Q7: Calculate measures of central tendency and measures of dispersion.

# %%
df.describe()
# Out:
#        Reason for absence  Month of absence  Day of the week     Seasons  \
# count          740.000000        740.000000       740.000000  740.000000
# mean            19.216216          6.324324         3.914865    2.544595
# std              8.433406          3.436287         1.421675    1.111831
# min              0.000000          0.000000         2.000000    1.000000
# 25%             13.000000          3.000000         3.000000    2.000000
# 50%             23.000000          6.000000         4.000000    3.000000
# 75%             26.000000          9.000000         5.000000    4.000000
# max             28.000000         12.000000         6.000000    4.000000
#
#        Transportation expense  Distance from Residence to Work  Service time  \
# count              740.000000                       740.000000    740.000000
# mean               221.329730                        29.631081     12.554054
# std                 66.952223                        14.836788      4.384873
# ...

# %%
#measures of central tendency
df.mean()
# Out:
# Reason for absence                     19.216216
# Month of absence                        6.324324
# Day of the week                         3.914865
# Seasons                                 2.544595
# Transportation expense                221.329730
# Distance from Residence to Work        29.631081
# Service time                           12.554054
# Work load Average/day              271490.235135
# Hit target                             94.587838
# Disciplinary failure                    0.054054
# Education                               1.291892
# Son                                     1.018919
# Social drinker                          0.567568
# Social smoker                           0.072973
# Pet                                     0.745946
# Weight                                 79.035135
# Height                                172.114865
# Body mass index                        26.677027
# Absenteeism time in hours               6.924324
# dtype: float64

# %%
#measures of central tendency
df.mode()
# Out:
#    Reason for absence  Month of absence  Day of the week  Seasons  \
# 0                  23                 3                2        4
#
#    Transportation expense  Distance from Residence to Work  Service time  \
# 0                     179                               26            18
#
#    Work load Average/day   Hit target  Disciplinary failure  Education  Son  \
# 0                  222196          93                     0          1    0
#
#    Social drinker  Social smoker  Pet  Weight  Height  Body mass index  \
# 0               1              0    0      89     170               31
#
#    Absenteeism time in hours
# 0                          8

# %%
#measures of central tendency
df.median()
# Out:
# Reason for absence                     23.0
# Month of absence                        6.0
# Day of the week                         4.0
# Seasons                                 3.0
# Transportation expense                225.0
# Distance from Residence to Work        26.0
# Service time                           13.0
# Work load Average/day              264249.0
# Hit target                             95.0
# Disciplinary failure                    0.0
# Education                               1.0
# Son                                     1.0
# Social drinker                          1.0
# Social smoker                           0.0
# Pet                                     0.0
# Weight                                 83.0
# Height                                170.0
# Body mass index                        25.0
# Absenteeism time in hours               3.0
# dtype: float64

# %%
#measures of central tendency
df.std()
# Out:
# Reason for absence                     8.433406
# Month of absence                       3.436287
# Day of the week                        1.421675
# Seasons                                1.111831
# Transportation expense                66.952223
# Distance from Residence to Work       14.836788
# Service time                           4.384873
# Work load Average/day              39058.116188
# Hit target                             3.779313
# Disciplinary failure                   0.226277
# Education                              0.673238
# Son                                    1.098489
# Social drinker                         0.495749
# Social smoker                          0.260268
# Pet                                    1.318258
# Weight                                12.883211
# Height                                 6.034995
# Body mass index                        4.285452
# Absenteeism time in hours             13.330998
# dtype: float64

# %% [markdown]
# ## Q8: Please convert BMI column into categories. For example, if BMI is < 19.5 code it as under weight, if weight is >= 19.5 and <= 25 code it as normal weight, if weight is >25 and <=30 code it as overweight and >30 code it as Obese.

# %%
df["BMI Categories"] = None

for j,i in enumerate (df["Body mass index"]):
    if i<19.5:
        df["BMI Categories"][j] = "under weight"
    elif i >=19.5 and i<=25 :
        df["BMI Categories"][j] = "normal weight"
    elif i>25 and i <=30 :
        df["BMI Categories"][j] = "overweight"        
    else:
        df["BMI Categories"][j] = "Obese"
# Out:
# C:\Users\Rudre\AppData\Local\Temp/ipykernel_24152/1654928312.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["BMI Categories"][j] = "overweight"
# C:\Users\Rudre\AppData\Local\Temp/ipykernel_24152/1654928312.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["BMI Categories"][j] = "Obese"
# C:\Users\Rudre\AppData\Local\Temp/ipykernel_24152/1654928312.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
df.head(10)
# Out:
#    Reason for absence  Month of absence  Day of the week  Seasons  \
# 0                  26                 7                3        1
# 1                   0                 7                3        1
# 2                  23                 7                4        1
# 3                   7                 7                5        1
# 4                  23                 7                5        1
# 5                  23                 7                6        1
# 6                  22                 7                6        1
# 7                  23                 7                6        1
# 8                  19                 7                2        1
# 9                  22                 7                2        1
#
#    Transportation expense  Distance from Residence to Work  Service time  \
# 0                     289                               36            13
# 1                     118                               13            18
# ...

# %% [markdown]
# ## Q9: Please determine which season had more absences in a given absenteeism dataset? Please tell us the name of season not number.

# %%
absenteeism_by_season = df.groupby("Seasons")["Absenteeism time in hours"].sum()
most_absence = absenteeism_by_season.idxmax()

print(absenteeism_by_season)
print("The Seasons with the most Absence was : ",most_absence)
# Out:
# Seasons
# 1    1241
# 2    1152
# 3    1492
# 4    1239
# Name: Absenteeism time in hours, dtype: int64
# The Seasons with the most Absence was :  3

# %% [markdown]
# ## Q10: Please determine which type of weight (overweight, normal weight, obese etc) had more absences in a given absenteeism dataset? Please tell the type of weight and total number.

# %%
absenteeism_by_BMI_Category = df.groupby("BMI Categories")["Absenteeism time in hours"].sum()
most_absence_1 = absenteeism_by_BMI_Category.idxmax()

print(absenteeism_by_BMI_Category)
print("The BMI category with the most absences was",most_absence_1)
# Out:
# BMI Categories
# Obese            1011
# normal weight    2738
# overweight       1122
# under weight      253
# Name: Absenteeism time in hours, dtype: int64
# The BMI category with the most absences was normal weight

# %% [markdown]
# ## Q11: Find all words in a string that start with a vowel.
# string = 'Apples are red, bananas are yellow, and oranges are orange.'

# %%
# Ans
import re 

string = 'Apples are red, bananas are yellow, and oranges are orange.'

check = re.findall(r'\b[aeiouAEIOU]\w*\b',string) 
print(check)
for word in check:
    print(word)
# Out:
# ['Apples', 'are', 'are', 'and', 'oranges', 'are', 'orange']
# Apples
# are
# are
# and
# oranges
# are
# orange

# %% [markdown]
# ## Q12: Replace all occurrences of the word "color" with "colour" in a string using regular expressions.
# string = 'The color of the sky is blue.'

# %%
string = 'The color of the sky is blue.'

new_str = re.sub(r"\bcolor\b", "colour",string)
new_str
# Out:
# 'The colour of the sky is blue.'

# %% [markdown]
# ## Q13: Extract all email addresses from a string and print them to the console.
# string = 'Please contact us at support@example.com for assistance or info@example.com for more information.'

# %%
string = 'Please contact us at support@example.com for assistance or info@example.com for more information.'

email = re.findall( r'\b[\w.-]+@[\w.-]+\.\w{2,}\b' ,string)
email
# Out:
# ['support@example.com', 'info@example.com']

# %% [markdown]
# ## Q14: Validate a US phone number using regular expressions. The phone number should be in the format "XXX-XXX-XXXX" (where X is a digit).
# phone_number = '123-456-7890'

# %%
phone_number = '123-456-7890'

if re.match('\d{3}-\d{3}-\d{4}$',phone_number):
    print("valid number")
else:
    print("It's not valid Number")
# Out:
# valid number

# %% [markdown]
# ## Q15: Parse a string of comma-separated key-value pairs and create a dictionary from them.
# string = 'key1=value1,key2=value2,key3=value3'

# %%
string = 'key1=value1,key2=value2,key3=value3'

key_value_pair = re.findall(r'([\w]+)=([\w]+)',string)
key_value_pair
# Out:
# {'key1': 'value1', 'key2': 'value2', 'key3': 'value3'}

# %% [markdown]
# ## Q16: Convert a string representing a date and time to a datetime object and print it to the console.
# date_string = '2023-03-24 16:30:00'

# %%
from datetime import datetime
date_string = '2023-03-24 16:30:00'

dt = datetime.strptime(date_string, '%Y-%m-%d %H:%M:%S' )
print(dt)
# Out:
# 2023-03-24 16:30:00

# %% [markdown]
# ## Q17: Calculate the time difference between two datetime objects in hours and minutes and print it to the console.
# start_time = datetime(2023, 3, 24, 16, 30, 0), end_time = datetime(2023, 3, 24, 18, 45, 0)

# %%
from datetime import datetime
start_time = datetime(2023, 3, 24, 16, 30, 0)
end_time = datetime(2023, 3, 24, 18, 45, 0)

diff = end_time - start_time 

print(diff)
hours = diff.seconds //3600
minutes = (diff.seconds // 60) % 60

print(f'The time difference between {start_time} and {end_time} is {hours} hours and {minutes} minutes.')
# Out:
# 2:15:00
# The time difference between 2023-03-24 16:30:00 and 2023-03-24 18:45:00 is 2 hours and 15 minutes.
