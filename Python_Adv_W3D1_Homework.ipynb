# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

mtcars = pd.read_excel("mtcars.xlsx")
mtcars.head()
# Out:
#                 Type   mpg  cyl   disp     hp  drat     wt   qsec   vs   am  \
# 0          Mazda RX4  21.0  6.0  160.0  110.0  3.90  2.620  16.46  0.0  1.0
# 1      Mazda RX4 Wag  21.0  6.0  160.0  110.0  3.90  2.875  17.02  0.0  1.0
# 2         Datsun 710  22.8  4.0  108.0   93.0  3.85  2.320  18.61  1.0  1.0
# 3     Hornet 4 Drive  21.4  6.0  258.0  110.0  3.08  3.215  19.44  1.0  0.0
# 4  Hornet Sportabout  18.7  8.0  360.0  175.0  3.15  3.440  17.02  0.0  0.0
#
#    gear  carb
# 0   4.0   4.0
# 1   4.0   4.0
# 2   4.0   1.0
# 3   3.0   1.0
# 4   3.0   2.0

# %% [markdown]
# ### Task 1
#
# It has been claimed that manual cars have highe mileage per gallon.
# Please create appropriate plot check them and compare cylinders
# also in the same plot.

# %%
data = mtcars[['Type', 'mpg', 'cyl']]

# plt.boxplot.mtcars(column ='mpg',by='Type')
# plt.xlabel('Car Type')
# plt.ylabel('Mileage per Gallon (mpg)')
# plt.title('Mileage per Gallon (mpg) by Car Type')

# plt.show()

# %% [markdown]
# ### Task 2
# Create a heatmap for mpg, disp, hp, wt and qsec columns.

# %% [markdown]
# ### Task 3
# Create histogram of mpg column and scatterplot between mpg and weight using subplot.

# %% [markdown]
# ### Task 4
# Examine the relationship between am and vs column and add legend at upper left.

# %% [markdown]
# ### Task 5
# Please use mtcars dataset and create a scatter plot between mpg (mile per gallon) and qsec. Scatter plot should be between vs 0 and 1.
